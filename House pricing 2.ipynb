# %%
import pandas as pd
import numpy as np
cols = ['SquareFeet', 'Bedrooms', 'Bathrooms', 'Neighborhood', 'YearBuilt','Price']
df = pd.read_csv("C:\\Users\\bvrvg\\Desktop\\Files\\ML\\Data sets\\housing_price_dataset.csv",header=None,skiprows=1,names=cols)
df
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0            2126         4          1        Rural       1969  215355.283618
# 1            2459         3          2        Rural       1980  195014.221626
# 2            1860         2          1       Suburb       1970  306891.012076
# 3            2294         2          1        Urban       1996  206786.787153
# 4            2130         5          2       Suburb       2001  272436.239065
# ...           ...       ...        ...          ...        ...            ...
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218
#
# [50000 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SquareFeet    50000 non-null  int64
#  1   Bedrooms      50000 non-null  int64
#  2   Bathrooms     50000 non-null  int64
#  3   Neighborhood  50000 non-null  object
#  4   YearBuilt     50000 non-null  int64
#  5   Price         50000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 2.3+ MB

# %%
df.describe()
# Out:
#          SquareFeet      Bedrooms     Bathrooms     YearBuilt          Price
# count  50000.000000  50000.000000  50000.000000  50000.000000   50000.000000
# mean    2006.374680      3.498700      1.995420   1985.404420  224827.325151
# std      575.513241      1.116326      0.815851     20.719377   76141.842966
# min     1000.000000      2.000000      1.000000   1950.000000  -36588.165397
# 25%     1513.000000      3.000000      1.000000   1967.000000  169955.860225
# 50%     2007.000000      3.000000      2.000000   1985.000000  225052.141166
# 75%     2506.000000      4.000000      3.000000   2003.000000  279373.630052
# max     2999.000000      5.000000      3.000000   2021.000000  492195.259972

# %%
df.Price.min()
# Out:
# -36588.16539749279

# %%
df[df.YearBuilt==1950]
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 145          1592         3          2       Suburb       1950  245299.209893
# 190          2038         2          3        Rural       1950  206119.181711
# 208          1748         4          2       Suburb       1950  142717.830227
# 229          2643         3          1       Suburb       1950  248155.871685
# 250          2282         5          1        Rural       1950  351438.546812
# ...           ...       ...        ...          ...        ...            ...
# 49865        2544         5          2        Urban       1950  205686.114115
# 49927        1146         5          2       Suburb       1950  193586.543064
# 49944        2728         5          3        Rural       1950  292994.766043
# 49966        2249         4          2        Urban       1950  266233.929673
# 49994        2426         5          2        Urban       1950  331497.091307
#
# [643 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
plt.hist(df.Price,bins=200)
plt.xlabel('Price')
plt.ylabel('count')
plt.show()

# %%
df2 = df[(df.Price>0)]
plt.hist(df2.Price,bins=200)
plt.xlabel('Price')
plt.ylabel('count')
plt.show()

# %%
df2.Bedrooms.unique()
# Out:
# array([4, 3, 2, 5], dtype=int64)

# %%
df2.Bathrooms.unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
import seaborn as sns

sns.pairplot(df2[['SquareFeet','Bedrooms','Bathrooms']],hue='Bedrooms',palette='Set2')
# Out:
# C:\Users\bvrvg\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
from matplotlib import figure as fig

# Get the screen size
# screen_width, screen_height = plt.matplotlib.pylab.full_screen()

# Set the figure size to fit screen
# plt.figure(figsize=(screen_width/100.0, screen_height/100.0), dpi=100)
x1 = df2.SquareFeet[(df2.Bedrooms==2)].astype(float)
y1 = df2.Price[(df2.Bedrooms==2)]

x2 = df2.SquareFeet[(df2.Bedrooms==3)].astype(float)
y2 = df2.Price[(df2.Bedrooms==3)]

x3 = df2.SquareFeet[(df2.Bedrooms==4)].astype(float)
y3 = df2.Price[(df2.Bedrooms==4)]

x4 = df2.SquareFeet[(df2.Bedrooms==5)].astype(float)
y4 = df2.Price[(df2.Bedrooms==5)]
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.plot(x1,y1,'*g')
plt.title('bedrooms=2')
plt.xlabel('Sq ft')
plt.ylabel('Price')

plt.subplot(2,2,2)
plt.plot(x2,y2,'^r')
plt.title('bedrooms=3')
plt.xlabel('Sq ft')
plt.ylabel('Price')

plt.subplot(2,2,3)
plt.plot(x3,y3,'*-b')
plt.title('bedrooms=4')
plt.xlabel('Sq ft')
plt.ylabel('Price')

plt.subplot(2,2,4)
plt.plot(x4,y4,'.-')
plt.title('bedrooms=5')
plt.xlabel('Sq ft')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
from matplotlib import figure as fig

# Get the screen size
# screen_width, screen_height = plt.matplotlib.pylab.full_screen()

# Set the figure size to fit screen
# plt.figure(figsize=(screen_width/100.0, screen_height/100.0), dpi=100)
x1 = df2.SquareFeet[(df2.Bedrooms==2)]
y1 = df2.Bathrooms[(df2.Bedrooms==2)]

x2 = df2.SquareFeet[(df2.Bedrooms==3)]
y2 = df2.Bathrooms[(df2.Bedrooms==3)]

x3 = df2.SquareFeet[(df2.Bedrooms==4)]
y3 = df2.Bathrooms[(df2.Bedrooms==4)]

x4 = df2.SquareFeet[(df2.Bedrooms==5)]
y4 = df2.Bathrooms[(df2.Bedrooms==5)]
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.plot(x1,y1,'*g')
plt.title('bedrooms=2')
plt.xlabel('Sq ft')
plt.ylabel('Bathrooms')

plt.subplot(2,2,2)
plt.plot(x2,y2,'^r')
plt.title('bedrooms=3')
plt.xlabel('Sq ft')
plt.ylabel('Bathrooms')

plt.subplot(2,2,3)
plt.plot(x3,y3,'*b')
plt.title('bedrooms=4')
plt.xlabel('Sq ft')
plt.ylabel('Bathrooms')

plt.subplot(2,2,4)
plt.plot(x4,y4,'.')
plt.title('bedrooms=5')
plt.xlabel('Sq ft')
plt.ylabel('Bathrooms')
# Out:
# Text(0, 0.5, 'Bathrooms')

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.plot(df2.SquareFeet[(df2.Neighborhood=='Rural')].head(10),df2.Price[(df2.Neighborhood=='Rural')].head(10),'*r')
plt.xlabel('Squarefeet')
plt.ylabel('Price')
plt.title('Rural')
plt.subplot(2,2,2)
plt.plot(df2.SquareFeet[(df2.Neighborhood=='Urban')],df2.Price[(df2.Neighborhood=='Urban')],'.b')
plt.xlabel('Squarefeet')
plt.ylabel('Price')
plt.title('Urban')
plt.subplot(2,2,3)
plt.plot(df2.SquareFeet[(df2.Neighborhood=='Suburb')],df2.Price[(df2.Neighborhood=='Suburb')],'^g')
plt.title('Suburban')
plt.xlabel('Squarefeet')
plt.ylabel('Price')
plt.show()

# %%
df2[(df2['Price']<10000) & (df2.YearBuilt>2000)]
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt        Price
# 15131        1178         4          2        Urban       2010  6124.032174
# 17216        1013         2          1       Suburb       2018   276.063516
# 27300        1041         4          1        Urban       2002  3926.857020
# 34761        1042         2          2        Urban       2014  6360.211403

# %%
df2[(df2.Price>100000)& (df2.Neighborhood=='Rural')]
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0            2126         4          1        Rural       1969  215355.283618
# 1            2459         3          2        Rural       1980  195014.221626
# 7            2044         4          3        Rural       1957  184992.321268
# 16           2123         5          2        Rural       1956  190773.148563
# 19           1130         4          3        Rural       1962  143050.201782
# ...           ...       ...        ...          ...        ...            ...
# 49987        2237         4          1        Rural       2011  227359.621341
# 49992        1818         4          1        Rural       1983  163683.675434
# 49995        1282         5          3        Rural       1975  100080.865895
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218
#
# [15815 rows x 6 columns]

# %%
df2[(df2.Neighborhood=='Urban')&(df2.Price>200000)]
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 3            2294         2          1        Urban       1996  206786.787153
# 8            2638         4          3        Urban       1959  377998.588152
# 18           2687         5          1        Urban       1979  239222.667797
# 20           2685         4          3        Urban       1999  405523.828317
# 24           2515         2          3        Urban       2013  307961.107382
# ...           ...       ...        ...          ...        ...            ...
# 49966        2249         4          2        Urban       1950  266233.929673
# 49967        2173         3          2        Urban       2016  245502.709315
# 49972        2009         4          1        Urban       2000  251924.652151
# 49984        2967         2          3        Urban       1960  345653.603641
# 49994        2426         5          2        Urban       1950  331497.091307
#
# [10478 rows x 6 columns]

# %%
plt.plot(df2.SquareFeet[(df2.Neighborhood=='Rural')&(df2.YearBuilt<2000)],df2.Price[(df2.Neighborhood=='Rural')&(df2.YearBuilt<2000)],'*r',label='1990\'s')
plt.plot(df2.SquareFeet[(df2.Neighborhood=='Rural')&(df2.YearBuilt>=2000)],df2.Price[(df2.Neighborhood=='Rural')&(df2.YearBuilt>=2000)],'.b',label='2000s')
plt.legend()
plt.xlabel('Sqft')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# Generate random data
x = np.random.standard_normal(100)
y = np.random.standard_normal(100)
z = np.random.standard_normal(100)

# Create a figure and a 3D Axes
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
ax.plot(x, y, z,'*r')

# Set labels
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

# Show plot
plt.show()

# %%
df2[(df2.YearBuilt==1950) & (df2.Neighborhood=='Rural')].describe()
# Out:
#         SquareFeet    Bedrooms   Bathrooms  YearBuilt          Price
# count   210.000000  210.000000  210.000000      210.0     210.000000
# mean   1961.328571    3.619048    1.990476     1950.0  217439.508506
# std     572.341628    1.156475    0.794662        0.0   74505.596794
# min    1017.000000    2.000000    1.000000     1950.0   31952.189583
# 25%    1442.250000    3.000000    1.000000     1950.0  168845.845195
# 50%    1922.000000    4.000000    2.000000     1950.0  211186.438155
# 75%    2464.250000    5.000000    3.000000     1950.0  266046.787456
# max    2990.000000    5.000000    3.000000     1950.0  395460.796669

# %%
x = df2[(df2.YearBuilt==1950) & (df2.Neighborhood=='Rural')].SquareFeet
y = df2[(df2.YearBuilt==1950) & (df2.Neighborhood=='Rural')].Price
plt.plot(x,y,'*')

# %%
df2[((df2.YearBuilt>1950) & (df2.YearBuilt<2000)) & (df2.Neighborhood=='Rural')]
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0            2126         4          1        Rural       1969  215355.283618
# 1            2459         3          2        Rural       1980  195014.221626
# 7            2044         4          3        Rural       1957  184992.321268
# 16           2123         5          2        Rural       1956  190773.148563
# 19           1130         4          3        Rural       1962  143050.201782
# ...           ...       ...        ...          ...        ...            ...
# 49979        2308         3          3        Rural       1961  290933.139475
# 49983        2082         2          2        Rural       1963  268700.034119
# 49992        1818         4          1        Rural       1983  163683.675434
# 49995        1282         5          3        Rural       1975  100080.865895
# 49998        2596         5          2        Rural       1984  380512.685957
#
# [11440 rows x 6 columns]

# %%
df3 = pd.get_dummies(df2,columns=['Bedrooms','Bathrooms','Neighborhood'],dtype=int)
df3.drop(columns=['Bedrooms_5','Bathrooms_3','Neighborhood_Rural'],axis=1,inplace=True)
df3
# Out:
#        SquareFeet  YearBuilt          Price  Bedrooms_2  Bedrooms_3  \
# 0            2126       1969  215355.283618           0           0
# 1            2459       1980  195014.221626           0           1
# 2            1860       1970  306891.012076           1           0
# 3            2294       1996  206786.787153           1           0
# 4            2130       2001  272436.239065           0           0
# ...           ...        ...            ...         ...         ...
# 49995        1282       1975  100080.865895           0           0
# 49996        2854       1988  374507.656727           1           0
# 49997        2979       1962  384110.555590           0           0
# 49998        2596       1984  380512.685957           0           0
# 49999        1572       2011  221618.583218           0           0
#
#        Bedrooms_4  Bathrooms_1  Bathrooms_2  Neighborhood_Suburb  \
# 0               1            1            0                    0
# ...

# %%
corr_matrix = df3.corr()
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',fmt='.2f')
# Out:
# <Axes: >

# %%
df3.describe()
# Out:
#          SquareFeet     YearBuilt          Price    Bedrooms_2    Bedrooms_3  \
# count  49978.000000  49978.000000   49978.000000  49978.000000  49978.000000
# mean    2006.752551   1985.404338  224931.667960      0.248729      0.253231
# std      575.350298     20.718407   75995.682992      0.432281      0.434867
# min     1000.000000   1950.000000     154.779120      0.000000      0.000000
# 25%     1514.000000   1967.000000  170007.487130      0.000000      0.000000
# 50%     2008.000000   1985.000000  225100.123857      0.000000      0.000000
# 75%     2506.000000   2003.000000  279395.826288      0.000000      1.000000
# max     2999.000000   2021.000000  492195.259972      1.000000      1.000000
#
#          Bedrooms_4   Bathrooms_1   Bathrooms_2  Neighborhood_Suburb  \
# count  49978.000000  49978.000000  49978.000000         49978.000000
# mean       0.248689      0.335087      0.334367             0.334467
# ...

# %%
df4 = df2[~((df2.Bedrooms==2)&(df2.Bathrooms==3)&(df2.SquareFeet<1350))]
df4
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0            2126         4          1        Rural       1969  215355.283618
# 1            2459         3          2        Rural       1980  195014.221626
# 2            1860         2          1       Suburb       1970  306891.012076
# 3            2294         2          1        Urban       1996  206786.787153
# 4            2130         5          2       Suburb       2001  272436.239065
# ...           ...       ...        ...          ...        ...            ...
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218
#
# [49314 rows x 6 columns]

# %%
df5 = df4[~((df4.Bedrooms==3)&(df4.SquareFeet<1200))]
df5 = df5[~(((df4.Bedrooms==3)&(df4.SquareFeet<1300) & (df4.Bathrooms==2)))]
df5 = df5[~((df5.Bedrooms==3)&(df5.SquareFeet<1400) & (df5.Bathrooms==3))]
df5
# Out:
# C:\Users\bvrvg\AppData\Local\Temp\ipykernel_13520\395055567.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df5 = df5[~(((df4.Bedrooms==3)&(df4.SquareFeet<1300) & (df4.Bathrooms==2)))]
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0            2126         4          1        Rural       1969  215355.283618
# 1            2459         3          2        Rural       1980  195014.221626
# 2            1860         2          1       Suburb       1970  306891.012076
# 3            2294         2          1        Urban       1996  206786.787153
# 4            2130         5          2       Suburb       2001  272436.239065
# ...           ...       ...        ...          ...        ...            ...
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# ...

# %%
df6 = df5[~((df5.Bedrooms==4) &(df5.SquareFeet<2150))]
df6
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 1            2459         3          2        Rural       1980  195014.221626
# 2            1860         2          1       Suburb       1970  306891.012076
# 3            2294         2          1        Urban       1996  206786.787153
# 4            2130         5          2       Suburb       2001  272436.239065
# 5            2095         2          3       Suburb       2020  198208.803907
# ...           ...       ...        ...          ...        ...            ...
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218
#
# [40377 rows x 6 columns]

# %%
df6[((df6.Bedrooms==4)&(df6.SquareFeet<2200) & (df6.Bathrooms==2))].describe()
# Out:
#         SquareFeet  Bedrooms  Bathrooms    YearBuilt          Price
# count   102.000000     102.0      102.0   102.000000     102.000000
# mean   2174.029412       4.0        2.0  1987.225490  240943.784050
# std      14.548285       0.0        0.0    20.742126   48261.968393
# min    2150.000000       4.0        2.0  1951.000000  132180.699227
# 25%    2162.000000       4.0        2.0  1970.500000  208962.755114
# 50%    2174.000000       4.0        2.0  1990.500000  242653.301466
# 75%    2187.750000       4.0        2.0  2005.000000  278688.933724
# max    2199.000000       4.0        2.0  2021.000000  351030.731678

# %%
df6 = df6[~((df6.Bedrooms==4)&(df6.SquareFeet<2200) & (df6.Bathrooms==2))]

# %%
df6 = df6[~((df6.Bedrooms==4)&(df6.SquareFeet<2700) & (df6.Bathrooms==3))]
df6
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 1            2459         3          2        Rural       1980  195014.221626
# 2            1860         2          1       Suburb       1970  306891.012076
# 3            2294         2          1        Urban       1996  206786.787153
# 4            2130         5          2       Suburb       2001  272436.239065
# 5            2095         2          3       Suburb       2020  198208.803907
# ...           ...       ...        ...          ...        ...            ...
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218
#
# [39070 rows x 6 columns]

# %%
df7 = df6[~((df6.Bedrooms==5)& (df6.SquareFeet<2700))]

# %%
df7 = df7[~((df7.Bedrooms==5)& (df7.SquareFeet<2800) &(df7.Bathrooms==2))]

# %%
df7 = df7[~((df7.Bedrooms==5)& (df7.SquareFeet<3000) &(df7.Bathrooms==3))]

# %%
df7.describe()
# Out:
#          SquareFeet      Bedrooms     Bathrooms     YearBuilt          Price
# count  27659.000000  27659.000000  27659.000000  27659.000000   27659.000000
# mean    2206.759933      2.797462      1.886077   1985.327271  240593.787427
# std      537.371937      0.826634      0.793941     20.745760   74226.452979
# min     1000.000000      2.000000      1.000000   1950.000000     154.779120
# 25%     1761.000000      2.000000      1.000000   1967.000000  188477.510497
# 50%     2276.000000      3.000000      2.000000   1985.000000  243137.789428
# 75%     2686.000000      3.000000      3.000000   2003.000000  293654.024828
# max     2999.000000      5.000000      3.000000   2021.000000  482577.163405

# %%
x1 = df7.SquareFeet[(df7.Bedrooms==2)]
y1 = df7.Bathrooms[(df7.Bedrooms==2)]

x2 = df7.SquareFeet[(df7.Bedrooms==3)]
y2 = df7.Bathrooms[(df7.Bedrooms==3)]

x3 = df7.SquareFeet[(df7.Bedrooms==4)]
y3 = df7.Bathrooms[(df7.Bedrooms==4)]

x4 = df7.SquareFeet[(df7.Bedrooms==5)]
y4 = df7.Bathrooms[(df7.Bedrooms==5)]
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.plot(x1,y1,'*g')
plt.title('bedrooms=2')
plt.xlabel('Sq ft')
plt.ylabel('Bathrooms')

plt.subplot(2,2,2)
plt.plot(x2,y2,'^r')
plt.title('bedrooms=3')
plt.xlabel('Sq ft')
plt.ylabel('Bathrooms')

plt.subplot(2,2,3)
plt.plot(x3,y3,'*b')
plt.title('bedrooms=4')
plt.xlabel('Sq ft')
plt.ylabel('Bathrooms')

plt.subplot(2,2,4)
plt.plot(x4,y4,'.')
plt.title('bedrooms=5')
plt.xlabel('Sq ft')
plt.ylabel('Bathrooms')
# Out:
# Text(0, 0.5, 'Bathrooms')

# %%
df8 = pd.get_dummies(df7,columns=['Bedrooms','Bathrooms','Neighborhood'],dtype=(int))
df8.drop(columns=['Bedrooms_5','Bathrooms_3','Neighborhood_Rural'])
df8
# Out:
#        SquareFeet  YearBuilt          Price  Bedrooms_2  Bedrooms_3  \
# 1            2459       1980  195014.221626           0           1
# 2            1860       1970  306891.012076           1           0
# 3            2294       1996  206786.787153           1           0
# 5            2095       2020  198208.803907           1           0
# 6            2724       1993  343429.319110           1           0
# ...           ...        ...            ...         ...         ...
# 49983        2082       1963  268700.034119           1           0
# 49984        2967       1960  345653.603641           1           0
# 49987        2237       2011  227359.621341           0           0
# 49989        2613       1992  233026.843614           0           1
# 49996        2854       1988  374507.656727           1           0
#
#        Bedrooms_4  Bedrooms_5  Bathrooms_1  Bathrooms_2  Bathrooms_3  \
# 1               0           0            0            1            0
# ...

# %%
corr_matrix = df8.corr()
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',fmt='.2f')
# Out:
# <Axes: >

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
rf_m = RandomForestRegressor()
df9 = df8.drop(columns=['Bedrooms_5','Bathrooms_3','Neighborhood_Rural'])
X = df9.drop(columns=['Price'])
Y = df9.Price
x_train , x_test, y_train , y_test = train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
rf_m.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = rf_m.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Calculate regression metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)  # If you are using NumPy
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R-squared (R^2):", r2)
# Out:
# Mean Absolute Error (MAE): 41877.74743823155
# Mean Squared Error (MSE): 2771751163.841696
# Root Mean Squared Error (RMSE): 52647.423145313536
# R-squared (R^2): 0.4978738397144611

# %%
rf_m.score(X,Y)
# Out:
# 0.7989150362783201

# %%
y_r1 = df7[((df7.Neighborhood=='Rural') & (df7.YearBuilt<2000))].Price
x_r1 = df7[((df7.Neighborhood=='Rural') & (df7.YearBuilt<2000))].SquareFeet
y_r2 = df7[((df7.Neighborhood=='Rural') & (df7.YearBuilt>=2000))].Price
x_r2 = df7[((df7.Neighborhood=='Rural') & (df7.YearBuilt>=2000))].SquareFeet


y_u1 = df7[((df7.Neighborhood=='Urban') & (df7.YearBuilt<2000))].Price
x_u1 = df7[((df7.Neighborhood=='Urban') & (df7.YearBuilt<2000))].SquareFeet
y_u2 = df7[((df7.Neighborhood=='Urban') & (df7.YearBuilt>=2000))].Price
x_u2 = df7[((df7.Neighborhood=='Urban') & (df7.YearBuilt>=2000))].SquareFeet

y_s1 = df7[((df7.Neighborhood=='Suburb') & (df7.YearBuilt<2000))].Price
x_s1 = df7[((df7.Neighborhood=='Suburb') & (df7.YearBuilt<2000))].SquareFeet
y_s2 = df7[((df7.Neighborhood=='Suburb') & (df7.YearBuilt>=2000))].Price
x_s2 = df7[((df7.Neighborhood=='Suburb') & (df7.YearBuilt>=2000))].SquareFeet

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.plot(x_r1,y_r1,"*",label='1950-1999')
plt.plot(x_r2,y_r2,".",label='2000-2021')
plt.xlabel('Sqft')
plt.ylabel('Price')
plt.title("rural")
plt.legend()
plt.grid()

plt.subplot(2,2,2)
plt.plot(x_u1,y_u1,"^",label='1950-1999')
plt.plot(x_u2,y_u2,'.',label='2000-2021')
plt.xlabel('Sqft')
plt.ylabel('Price')
plt.title("Urban")
plt.legend()
plt.grid()

plt.subplot(2,2,3)
plt.plot(x_s1,y_s1,'*',label='1950-1999')
plt.plot(x_s2,y_s2,'.',label='2000-2021')
plt.xlabel('Sqft')
plt.ylabel('Price')
plt.title("Suburban")
plt.grid()
plt.legend()
plt.show()

# %%
df7
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 1            2459         3          2        Rural       1980  195014.221626
# 2            1860         2          1       Suburb       1970  306891.012076
# 3            2294         2          1        Urban       1996  206786.787153
# 5            2095         2          3       Suburb       2020  198208.803907
# 6            2724         2          1       Suburb       1993  343429.319110
# ...           ...       ...        ...          ...        ...            ...
# 49983        2082         2          2        Rural       1963  268700.034119
# 49984        2967         2          3        Urban       1960  345653.603641
# 49987        2237         4          1        Rural       2011  227359.621341
# 49989        2613         3          2       Suburb       1992  233026.843614
# 49996        2854         2          2       Suburb       1988  374507.656727
#
# [27659 rows x 6 columns]

# %%
from sklearn.model_selection import cross_val_score
X2 = df9.SquareFeet
X2 = np.array(X2).reshape(-1, 1)
score_rf = cross_val_score(RandomForestRegressor(),X2,Y)
score_rf
# Out:
# array([0.49549259, 0.51258131, 0.50762256, 0.50874741, 0.51766452])

# %%
score_rf2 = cross_val_score(RandomForestRegressor(),X,Y)

# %%
score_rf2
# Out:
# array([0.48066873, 0.50106735, 0.50298631, 0.49521018, 0.49851565])

# %%
X3 = df2.SquareFeet
X3 = np.array(X3).reshape(-1,1)
score_rf3 = cross_val_score(RandomForestRegressor(),X3,df2.Price)
score_rf3
# Out:
# array([0.53247029, 0.54331921, 0.5457696 , 0.54395548, 0.54294763])

# %%
rf_ml = RandomForestRegressor()
rf_ml.fit(X3,df2.Price)
# Out:
# RandomForestRegressor()

# %%
# !pip install joblib

# %%
import joblib as jb
jb.dump(rf_ml,"House price")
# Out:
# ['House price']
